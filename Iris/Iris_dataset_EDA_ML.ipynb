# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
iris_df=sns.load_dataset('iris') #importing from seaborn

# %%
iris_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal_length    150 non-null float64
# sepal_width     150 non-null float64
# petal_length    150 non-null float64
# petal_width     150 non-null float64
# species         150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris_df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ## Univariate Analysis

# %%
sns.boxplot(iris_df['sepal_length'],orient="v",palette="Paired")

# %%
sns.boxplot(iris_df['sepal_width'],orient="v",palette="Paired")

# %%
sns.boxplot(iris_df['petal_length'],orient="v",palette="Paired")

# %%
sns.boxplot(iris_df['sepal_width'],orient="v",color='y',palette="Paired")

# %% [markdown]
# ## Bivariate Analysis

# %%
iris_df['species'].value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
sns.scatterplot(iris_df['sepal_length'],iris_df['petal_length'],color='r')
plt.title('Scatter plot')
# Out:
# Text(0.5, 1.0, 'Scatter plot')

# %%
sns.scatterplot(iris_df['sepal_length'],iris_df['petal_length'],hue=iris_df['species'])
plt.title('Scatter plot')
# Out:
# Text(0.5, 1.0, 'Scatter plot')

# %%
#from this graph we can say that the petal and sepal lenth of the setosa species is less than the other 2
#and versicolor has more than stosa but less than viginica

# %%
sns.scatterplot(iris_df['sepal_width'],iris_df['petal_width'],hue=iris_df['species'])
plt.title('Scatter plot')
# Out:
# Text(0.5, 1.0, 'Scatter plot')

# %%
sns.boxplot(iris_df['species'],iris_df['sepal_length'])

# %%
sns.jointplot(iris_df['sepal_length'],iris_df['sepal_width'],kind='resid',color='r')

# %%
sns.jointplot(iris_df['sepal_length'],iris_df['sepal_width'],kind='kde')

# %%
sns.jointplot(iris_df['sepal_length'],iris_df['sepal_width'],kind='hex',color='r')

# %%
sns.set_style("whitegrid");
sns.pairplot(iris_df,hue="species",size=3);
plt.show()
# Out:
# C:\Users\shrey\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.countplot(iris_df['species'])

# %% [markdown]
# ## The ML Model

# %%
array = iris_df.values
x = array[:,0:4]
y = array[:,4]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.5)

# %%
from sklearn import tree
classifier=tree.DecisionTreeClassifier()

# %%
classifier.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
predictions=classifier.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,predictions))
# Out:
# 0.9466666666666667
